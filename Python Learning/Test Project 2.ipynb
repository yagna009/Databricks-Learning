# %%
print("Hello World \U0001F44B, \n")
# Out:
# Hello World 👋,

# %%
name = "Kishan"
age = 35
salary = 150000
print(f"My name is {name}, I am {age} years old and my salary is {salary}")
# Out:
# My name is Kishan, I am 35 years old and my salary is 150000

# %%
name = input("Enter Your Name")
age = int(input("Enter Your Age"))
salary = int(input("Enter your Salary Expectation"))
location = "India"

print(f" Your name is {name}, You are {age} years old and your salary expectation is {salary}. Your location is {location}")

if age <= 30:
    if salary <= 100000:
        print(f"Hey, {name} you are Eligible for this job")
    else:
        print(f"Hey, {name} sorry, you are Not Eligible for this job")
else:
    print(f"Hey, {name} sorry, you are Not Eligible for this job")

print(f"Thank you {name} for your time")
# Out:
# Enter Your Name Yagna
# Enter Your Age 30
# Enter your Salary Expectation 120000
#  Your name is Yagna, You are 30 years old and your salary expectation is 120000. Your location is India
# Hey, Yagna sorry, you are Not Eligible for this job
# Thank you Yagna for your time
